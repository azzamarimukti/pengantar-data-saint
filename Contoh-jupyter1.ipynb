# %%
import numpy as np

a = [10,3,5,12,50]
b = [5,4,3,2,1]

aa = np.array(a)
ab = np.array(b)

print("perkalian a dan b = ", aa * b)
print("pembagian a dan b = ", aa / b)
print("penjumlahan a dan b = ", aa + b)
print("pengurangan a dan b = ", aa - b)
# Out:
# perkalian a dan b =  [50 12 15 24 50]
# pembagian a dan b =  [ 2.          0.75        1.66666667  6.         50.        ]
# penjumlahan a dan b =  [15  7  8 14 51]
# pengurangan a dan b =  [ 5 -1  2 10 49]
